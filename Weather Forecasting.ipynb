# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
a=pd.read_csv('https://raw.githubusercontent.com/gmonu/Data-Visualization-using-Python/master/Weather_Data_Visualize/Test.csv')

# %%
a.head()
# Out:
#           date_time is_holiday  air_pollution_index  humidity  wind_speed  \
# 0  18-05-2017 00:00       None                 73.0      63.0         1.0
# 1  18-05-2017 00:00       None                251.0      63.0         1.0
# 2  18-05-2017 00:00       None                 75.0      56.0         1.0
# 3  18-05-2017 01:00       None                 98.0      56.0         1.0
# 4  18-05-2017 01:00       None                283.0      56.0         1.0
#
#    wind_direction  visibility_in_miles  dew_point  temperature  rain_p_h  \
# 0            27.0                  4.0        4.0       285.15       0.0
# 1            27.0                  4.0        4.0       285.15       0.0
# 2             0.0                  1.0        1.0       285.15       0.0
# 3           351.0                  2.0        2.0       284.79       0.0
# 4           351.0                  1.0        1.0       284.79       0.0
#
#    snow_p_h  clouds_all weather_type      weather_description
# ...

# %%
a.columns
# Out:
# Index(['date_time', 'is_holiday', 'air_pollution_index', 'humidity',
#        'wind_speed', 'wind_direction', 'visibility_in_miles', 'dew_point',
#        'temperature', 'rain_p_h', 'snow_p_h', 'clouds_all', 'weather_type',
#        'weather_description'],
#       dtype='object')

# %%
sns.barplot(a['humidity'],a['temperature']);

# %%
sns.distplot(a['humidity']);

# %%
sns.displot(a['visibility_in_miles']);

# %%
sns.jointplot(a['air_pollution_index'],a['temperature']);

# %%
sns.jointplot(a['humidity'],a['temperature'],kind="hex");

# %%
sns.jointplot(a['humidity'],a['temperature'],kind="kde");

# %%
sns.pairplot(a[['humidity','temperature','air_pollution_index']]);

# %%
sns.stripplot(a['weather_type'],a['temperature']);

# %%
sns.swarmplot(a['humidity'],a['temperature']);

# %%
sns.boxplot(a['humidity'], a['temperature'], hue=a['weather_type']);

# %%
sns.barplot(a['humidity'], a['temperature'], hue=a['weather_type'])
# Out:
# <AxesSubplot:xlabel='humidity', ylabel='temperature'>

# %%
sns.countplot(a['weather_type']);

# %%
sns.pointplot(a['humidity'], a['temperature'], hue=a['weather_type']);

# %%
sns.lmplot(x="humidity", y="temperature", data=a)

# %%
sns.lmplot(x="humidity", y="temperature", hue="weather_type", data=a);
